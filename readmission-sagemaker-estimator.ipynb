# %% [markdown]
# ## Launching a training job with the Python SDK

# %%
import sagemaker
from sagemaker import get_execution_role
from sagemaker.sklearn.estimator import SKLearn

sagemaker_session = sagemaker.Session()

# Get a SageMaker-compatible role used by this Notebook Instance.
role = get_execution_role()

# %%
s3_bucket = 'readmission-data'
s3_key_prefix = 'processed-data'
s3_kms_id = '3a90a5d2-2ba8-4942-b9df-9a27ff7bf412'
s3_output_key_prefix = 'models'
s3_train_data = 's3://{}/{}/'.format(s3_bucket, s3_key_prefix)
s3_output_data = 's3://{}/{}/'.format(s3_bucket, s3_output_key_prefix)

print ('training data location:', s3_train_data)
print ('model output location', s3_output_data)
sklearn_model = SKLearn(entry_point='sklearn-train.py',
                            train_instance_type='ml.p3.2xlarge',
                            train_instance_count=1,
                            train_volume_size = 20,
                            framework_version='0.20.0',
                            role=role,
                            input_mode='File',
                            source_dir='train_scripts',
                            sagemaker_session=sagemaker_session,
                            output_path = s3_output_data,
                            output_kms_key = '3a90a5d2-2ba8-4942-b9df-9a27ff7bf412',
                            encrypt_inter_container_traffic = True,
                            hyperparameters = {'estimators': 20})
sklearn_model.fit({'train':s3_train_data})
# Out:
# training data location: s3://readmission-data/processed-data/
# model output location s3://readmission-data/models/
# 2019-10-30 00:45:21 Starting - Starting the training job...
# 2019-10-30 00:45:33 Starting - Launching requested ML instances......
# 2019-10-30 00:46:32 Starting - Preparing the instances for training...
# 2019-10-30 00:47:18 Downloading - Downloading input data...............
# 2019-10-30 00:49:48 Training - Downloading the training image...
# 2019-10-30 00:50:07 Training - Training image download completed. Training in progress.2019-10-30 00:50:07,117 sagemaker-containers INFO     Imported framework sagemaker_sklearn_container.training
# 2019-10-30 00:50:07,141 sagemaker_sklearn_container.training INFO     Invoking user training script.
# 2019-10-30 00:50:07,472 sagemaker-containers INFO     Module sklearn-train does not provide a setup.py.
# Generating setup.py
# 2019-10-30 00:50:07,472 sagemaker-containers INFO     Generating setup.cfg
# 2019-10-30 00:50:07,472 sagemaker-containers INFO     Generating MANIFEST.in
# 2019-10-30 00:50:07,472 sagemaker-containers INFO     Installing module with the following command:
# /miniconda3/bin/python -m pip install . -r requirements.txt
# Processing /opt/ml/code
# Collecting matplotlib (from -r requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/19/7a/60bd79c5d79559150f8bba866dd7d434f0a170312e4d15e8aefa5faba294/matplotlib-3.1.1-cp37-cp37m-manylinux1_x86_64.whl (13.1MB)
# Requirement already satisfied: pyarrow in /miniconda3/lib/python3.7/site-packages (from -r requirements.txt (line 2)) (0.14.1)
# Collecting s3fs (from -r requirements.txt (line 3))
#   Downloading https://files.pythonhosted.org/packages/3e/0d/d5f7ef4a3c2237b71e7e406ed6f512815874bfc5c042ebd680bd29d7d06e/s3fs-0.3.5.tar.gz (46kB)
# Requirement already satisfied: python-dateutil>=2.1 in /miniconda3/lib/python3.7/site-packages (from matplotlib->-r requirements.txt (line 1)) (2.8.0)
# Requirement already satisfied: numpy>=1.11 in /miniconda3/lib/python3.7/site-packages (from matplotlib->-r requirements.txt (line 1)) (1.17.3)
# Collecting pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.1 (from matplotlib->-r requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/11/fa/0160cd525c62d7abd076a070ff02b2b94de589f1a9789774f17d7c54058e/pyparsing-2.4.2-py2.py3-none-any.whl (65kB)
# Collecting kiwisolver>=1.0.1 (from matplotlib->-r requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/93/f8/518fb0bb89860eea6ff1b96483fbd9236d5ee991485d0f3eceff1770f654/kiwisolver-1.1.0-cp37-cp37m-manylinux1_x86_64.whl (90kB)
# Collecting cycler>=0.10 (from matplotlib->-r requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/f7/d2/e07d3ebb2bd7af696440ce7e754c59dd546ffe1bbe732c8ab68b9c834e61/cycler-0.10.0-py2.py3-none-any.whl
# Requirement already satisfied: six>=1.0.0 in /miniconda3/lib/python3.7/site-packages (from pyarrow->-r requirements.txt (line 2)) (1.12.0)
# Requirement already satisfied: boto3>=1.9.91 in /miniconda3/lib/python3.7/site-packages (from s3fs->-r requirements.txt (line 3)) (1.9.253)
# Requirement already satisfied: botocore>=1.12.91 in /miniconda3/lib/python3.7/site-packages (from s3fs->-r requirements.txt (line 3)) (1.12.253)
# Collecting fsspec>=0.2.2 (from s3fs->-r requirements.txt (line 3))
#   Downloading https://files.pythonhosted.org/packages/54/18/59f1850336568168144a746afa7199a0311f1a89bdb7b0d8e8b50d2c3d93/fsspec-0.5.2.tar.gz (64kB)
# Requirement already satisfied: setuptools in /miniconda3/lib/python3.7/site-packages (from kiwisolver>=1.0.1->matplotlib->-r requirements.txt (line 1)) (41.4.0)
# Requirement already satisfied: s3transfer<0.3.0,>=0.2.0 in /miniconda3/lib/python3.7/site-packages (from boto3>=1.9.91->s3fs->-r requirements.txt (line 3)) (0.2.1)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /miniconda3/lib/python3.7/site-packages (from boto3>=1.9.91->s3fs->-r requirements.txt (line 3)) (0.9.4)
# Requirement already satisfied: urllib3<1.26,>=1.20; python_version >= "3.4" in /miniconda3/lib/python3.7/site-packages (from botocore>=1.12.91->s3fs->-r requirements.txt (line 3)) (1.24.2)
# Requirement already satisfied: docutils<0.16,>=0.10 in /miniconda3/lib/python3.7/site-packages (from botocore>=1.12.91->s3fs->-r requirements.txt (line 3)) (0.15.2)
# Building wheels for collected packages: s3fs, sklearn-train, fsspec
#   Building wheel for s3fs (setup.py): started
#   Building wheel for s3fs (setup.py): finished with status 'done'
#   Created wheel for s3fs: filename=s3fs-0.3.5-cp37-none-any.whl size=18974 sha256=779f8d46b991ffa8571d2b198d0b4139e626f0fdaab58becc3702ac054f7a89a
#   Stored in directory: /root/.cache/pip/wheels/cb/d9/09/6fca70931372224b64d1a134cc60eb525c3b83991d54dd31e0
#   Building wheel for sklearn-train (setup.py): started
#   Building wheel for sklearn-train (setup.py): finished with status 'done'
#   Created wheel for sklearn-train: filename=sklearn_train-1.0.0-py2.py3-none-any.whl size=15895 sha256=bb97dc63eeb090dcf22c6e2b8cf6d5e544c8d4a3cc843a15459741a015f30ccc
#   Stored in directory: /tmp/pip-ephem-wheel-cache-xdcve829/wheels/35/24/16/37574d11bf9bde50616c67372a334f94fa8356bc7164af8ca3
#   Building wheel for fsspec (setup.py): started
#   Building wheel for fsspec (setup.py): finished with status 'done'
#   Created wheel for fsspec: filename=fsspec-0.5.2-cp37-none-any.whl size=57401 sha256=6cef09eff67c7f2459a92baa104e324c0b5fe0ccd03ee86f7f01c8725dedb24e
#   Stored in directory: /root/.cache/pip/wheels/6f/da/92/d854f08bad999b49e3ff84d5ddb3646f755fb24fe4d95c3356
# Successfully built s3fs sklearn-train fsspec
# Installing collected packages: pyparsing, kiwisolver, cycler, matplotlib, fsspec, s3fs, sklearn-train
# Successfully installed cycler-0.10.0 fsspec-0.5.2 kiwisolver-1.1.0 matplotlib-3.1.1 pyparsing-2.4.2 s3fs-0.3.5 sklearn-train-1.0.0
# 2019-10-30 00:50:12,402 sagemaker-containers INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "train": "/opt/ml/input/data/train"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_sklearn_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "estimators": 20
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "train": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "sagemaker-scikit-learn-2019-10-30-00-45-21-095",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://readmission-data/sagemaker-scikit-learn-2019-10-30-00-45-21-095/source/sourcedir.tar.gz",
#     "module_name": "sklearn-train",
#     "network_interface_name": "eth0",
#     "num_cpus": 8,
#     "num_gpus": 1,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "sklearn-train.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"estimators":20}
# SM_USER_ENTRY_POINT=sklearn-train.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["train"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=sklearn-train
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_sklearn_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=8
# SM_NUM_GPUS=1
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://readmission-data/sagemaker-scikit-learn-2019-10-30-00-45-21-095/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"train":"/opt/ml/input/data/train"},"current_host":"algo-1","framework_module":"sagemaker_sklearn_container.training:main","hosts":["algo-1"],"hyperparameters":{"estimators":20},"input_config_dir":"/opt/ml/input/config","input_data_config":{"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"sagemaker-scikit-learn-2019-10-30-00-45-21-095","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://readmission-data/sagemaker-scikit-learn-2019-10-30-00-45-21-095/source/sourcedir.tar.gz","module_name":"sklearn-train","network_interface_name":"eth0","num_cpus":8,"num_gpus":1,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"sklearn-train.py"}
# SM_USER_ARGS=["--estimators","20"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# SM_HP_ESTIMATORS=20
# PYTHONPATH=/miniconda3/bin:/miniconda3/lib/python37.zip:/miniconda3/lib/python3.7:/miniconda3/lib/python3.7/lib-dynload:/miniconda3/lib/python3.7/site-packages
#
# Invoking script with the following command:
#
# /miniconda3/bin/python -m sklearn-train --estimators 20
#
#
# /miniconda3/lib/python3.7/site-packages/sklearn/externals/joblib/externals/cloudpickle/cloudpickle.py:47: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   import imp
# Reading the training input file
# Training input load complete
# Test prevalence(n = 2294293): 0.08100185983220103
# Valid prevalence(n = 2294293): 0.08097788730558826
# Train all prevalence(n = 10706699): 0.08127257523537366
# all samples (n = 15295285)
# Train prevalence (n = 1740322): 0.5
# starting to fit the model
# Model fit complete
# RF Accuracy 0.8566090209290611
# roc score 0.8566192522759817
# Classification Report
# ==================================================
#               precision    recall  f1-score   support
#
#            0       0.87      0.84      0.85    261187
#            1       0.84      0.88      0.86    260910
#
#    micro avg       0.86      0.86      0.86    522097
#    macro avg       0.86      0.86      0.86    522097
# weighted avg       0.86      0.86      0.86    522097
#
# Confusion matrix, without normalization
# [[218701  42486]
#  [ 32378 228532]]
#
# 2019-10-30 01:01:53 Uploading - Uploading generated training modelAverage precision-recall score RF: 0.9377977522694572
# List of significant features correlated to readmission within 30 days
# ('providers_utilization', 0.168)
# ('organizations_revenue', 0.1545)
# ('patient_healthcare_coverage', 0.0777)
# ('patient_healthcare_expenses', 0.0678)
# ('procedures_base_cost', 0.0605)
# ('age', 0.058)
# ('encounters_code_424441002', 0.0541)
# ('encounters_payer_coverage', 0.0215)
# ('procedures_code_225158009.0', 0.0194)
# ('procedures_code_180256009.0', 0.0138)
# ('providers_speciality_M', 0.0131)
# ('encounters_encounterclass_outpatient', 0.0113)
# ('procedures_code_274804006.0', 0.0108)
# ('encounters_code_185345009', 0.01)
# ('encounters_reasoncode_72892002', 0.0093)
# ('encounters_code_185347001', 0.0092)
# ('encounters_code_702927004', 0.0084)
# ('encounters_code_424619006', 0.0083)
# ('patient_gender_M', 0.0082)
# ('encounters_code_390906007', 0.0069)
# ('encounters_code_185349003', 0.0065)
# ('encounters_encounterclass_urgentcare', 0.006)
# ('encounters_encounterclass_inpatient', 0.0054)
# ('encounters_code_371883000', 0.0053)
# ('encounters_encounterclass_emergency', 0.005)
# ('patient_marital_M', 0.005)
# ('procedures_code_118001005.0', 0.005)
# ('procedures_code_265764009.0', 0.0048)
# ('encounters_code_698314001', 0.0047)
# ('procedures_code_1.6335031000119104e+16', 0.0045)
# ('encounters_reasoncode_55822004', 0.0044)
# ('encounters_reasoncode_271737000', 0.0043)
# ('procedures_code_104091002.0', 0.0038)
# ('encounters_code_169762003', 0.0037)
# ('patient_ethnicity_irish', 0.0037)
# ('patient_marital_S', 0.0035)
# ('procedures_code_171207006.0', 0.0032)
# ('patient_ethnicity_italian', 0.0031)
# ('patient_ethnicity_english', 0.003)
# ('encounters_code_50849002', 0.0029)
# ('encounters_code_183460006', 0.0028)
# ('procedures_code_443529005.0', 0.0028)
# ('patient_ethnicity_french', 0.0026)
# ('patient_race_white', 0.0025)
# ('procedures_code_268556000.0', 0.0025)
# ('procedures_code_271442007.0', 0.0025)
# ('procedures_code_399014008.0', 0.0025)
# ('patient_ethnicity_german', 0.0022)
# ('procedures_code_275833003.0', 0.0022)
# ('procedures_code_65200003.0', 0.0022)
# ('patient_ethnicity_american', 0.0021)
# ('patient_ethnicity_polish', 0.0021)
# ('patient_ethnicity_portuguese', 0.002)
# ('procedures_code_428191000124101.0', 0.002)
# ('encounters_code_448337001', 0.0019)
# ('procedures_code_76601001.0', 0.0019)
# ('encounters_reasoncode_88805009', 0.0018)
# ('patient_ethnicity_french_canadian', 0.0018)
# ('procedures_code_5880005.0', 0.0018)
# ('patient_race_black', 0.0017)
# ('encounters_reasoncode_254837009', 0.0016)
# ('patient_ethnicity_chinese', 0.0016)
# ('patient_race_hispanic', 0.0016)
# ('procedures_code_180325003.0', 0.0016)
# ('encounters_reasoncode_444814009', 0.0014)
# ('patient_ethnicity_scottish', 0.0014)
# ('procedures_code_703423002.0', 0.0014)
# ('encounters_code_410429000', 0.0013)
# ('patient_ethnicity_puerto_rican', 0.0013)
# ('patient_ethnicity_russian', 0.0013)
# ('encounters_code_308335008', 0.0012)
# ('encounters_reasoncode_126906006', 0.0012)
# ('encounters_reasoncode_65275009', 0.0012)
# ('procedures_code_169673001.0', 0.0012)
# ('procedures_code_73761001.0', 0.0012)
# ('patient_ethnicity_asian_indian', 0.0011)
# ('patient_ethnicity_dominican', 0.0011)
# ('patient_ethnicity_greek', 0.0011)
# ('patient_ethnicity_swedish', 0.0011)
# ('patient_ethnicity_west_indian', 0.0011)
# ('encounters_code_270427003', 0.001)
# ('encounters_reasoncode_10509002', 0.0009)
# ('encounters_reasoncode_65363002', 0.0009)
# ('patient_ethnicity_central_american', 0.0009)
# ('procedures_code_169230002.0', 0.0009)
# ('procedures_code_31208007.0', 0.0009)
# ('procedures_code_33195004.0', 0.0009)
# ('procedures_code_398171003.0', 0.0009)
# ('patient_ethnicity_mexican', 0.0008)
# ('patient_ethnicity_south_american', 0.0008)
# ('procedures_code_85548006.0', 0.0008)
# ('encounters_reasoncode_195662009', 0.0007)
# ('encounters_reasoncode_36971009', 0.0007)
# ('procedures_code_15081005.0', 0.0007)
# ('procedures_code_18946005.0', 0.0007)
# ('procedures_code_274474001.0', 0.0007)
# ('procedures_code_310861008.0', 0.0007)
# ('procedures_code_386394001.0', 0.0007)
# ('procedures_code_714812005.0', 0.0007)
# ('encounters_reasoncode_239873007', 0.0006)
# ('encounters_total_claim_cost', 0.0006)
# ('procedures_code_1015401000000102.0', 0.0006)
# ('procedures_code_312681000.0', 0.0006)
# ('encounters_base_encounter_cost', 0.0005)
# ('encounters_code_308540004', 0.0005)
# ('encounters_code_310061009', 0.0005)
# ('encounters_code_410410006', 0.0005)
# ('encounters_reasoncode_192127007', 0.0005)
# ('encounters_reasoncode_363406005', 0.0005)
# ('encounters_reasoncode_55680006', 0.0005)
# ('encounters_reasoncode_75498004', 0.0005)
# ('procedures_code_11466000.0', 0.0005)
# ('procedures_code_169690007.0', 0.0005)
# ('procedures_code_18286008.0', 0.0005)
# ('procedures_code_232717009.0', 0.0005)
# ('procedures_code_252160004.0', 0.0005)
# ('procedures_code_274031008.0', 0.0005)
# ('encounters_code_170838006', 0.0004)
# ('encounters_code_230690007', 0.0004)
# ('encounters_code_394701000', 0.0004)
# ('encounters_reasoncode_128613002', 0.0004)
# ('encounters_reasoncode_233678006', 0.0004)
# ('encounters_reasoncode_47505003', 0.0004)
# ('encounters_reasoncode_67811000119102', 0.0004)
# ('encounters_reasoncode_74400008', 0.0004)
# ('procedures_code_10383002.0', 0.0004)
# ('procedures_code_117010004.0', 0.0004)
# ('procedures_code_367336001.0', 0.0004)
# ('procedures_code_399208008.0', 0.0004)
# ('procedures_code_430193006.0', 0.0004)
# ('procedures_code_47758006.0', 0.0004)
# ('procedures_code_51116004.0', 0.0004)
# ('procedures_code_66348005.0', 0.0004)
# ('procedures_code_71651007.0', 0.0004)
# ('procedures_code_90470006.0', 0.0004)
# ('encounters_code_183495009', 0.0003)
# ('encounters_code_185317003', 0.0003)
# ('encounters_code_305408004', 0.0003)
# ('encounters_code_439740005', 0.0003)
# ('encounters_reasoncode_109838007', 0.0003)
# ('encounters_reasoncode_156073000', 0.0003)
# ('encounters_reasoncode_24079001', 0.0003)
# ('encounters_reasoncode_62106007', 0.0003)
# ('patient_ethnicity_american_indian', 0.0003)
# ('patient_race_native', 0.0003)
# ('procedures_code_127783003.0', 0.0003)
# ('procedures_code_14768001.0', 0.0003)
# ('procedures_code_162676008.0', 0.0003)
# ('procedures_code_237001001.0', 0.0003)
# ('procedures_code_305428000.0', 0.0003)
# ('procedures_code_31676001.0', 0.0003)
# ('procedures_code_395123002.0', 0.0003)
# ('procedures_code_415070008.0', 0.0003)
# ('procedures_code_415300000.0', 0.0003)
# ('procedures_code_433112001.0', 0.0003)
# ('procedures_code_447365002.0', 0.0003)
# ('procedures_code_68254000.0', 0.0003)
# ('procedures_code_699253003.0', 0.0003)
# ('procedures_code_90226004.0', 0.0003)
# ('encounters_code_170837001', 0.0002)
# ('encounters_code_183452005', 0.0002)
# ('encounters_code_185389009', 0.0002)
# ('encounters_code_210098006', 0.0002)
# ('encounters_code_316744009', 0.0002)
# ('encounters_code_56876005', 0.0002)
# ('encounters_reasoncode_195967001', 0.0002)
# ('encounters_reasoncode_201834006', 0.0002)
# ('encounters_reasoncode_239872002', 0.0002)
# ('encounters_reasoncode_26929004', 0.0002)
# ('encounters_reasoncode_307731004', 0.0002)
# ('encounters_reasoncode_403190006', 0.0002)
# ('encounters_reasoncode_43878008', 0.0002)
# ('encounters_reasoncode_90560007', 0.0002)
# ('procedures_code_117015009.0', 0.0002)
# ('procedures_code_169553002.0', 0.0002)
# ('procedures_code_228557008.0', 0.0002)
# ('procedures_code_23426006.0', 0.0002)
# ('procedures_code_236974004.0', 0.0002)
# ('procedures_code_28163009.0', 0.0002)
# ('procedures_code_287664005.0', 0.0002)
# ('procedures_code_288086009.0', 0.0002)
# ('procedures_code_301807007.0', 0.0002)
# ('procedures_code_385798007.0', 0.0002)
# ('procedures_code_395142003.0', 0.0002)
# ('procedures_code_43075005.0', 0.0002)
# ('encounters_code_183478001', 0.0001)
# ('encounters_code_223484005', 0.0001)
# ('encounters_code_86013001', 0.0001)
# ('encounters_reasoncode_124171000119105', 0.0001)
# ('encounters_reasoncode_16114001', 0.0001)
# ('encounters_reasoncode_162573006', 0.0001)
# ('encounters_reasoncode_196416002', 0.0001)
# ('encounters_reasoncode_232353008', 0.0001)
# ('encounters_reasoncode_263102004', 0.0001)
# ('encounters_reasoncode_267253006', 0.0001)
# ('encounters_reasoncode_301011002', 0.0001)
# ('encounters_reasoncode_33737001', 0.0001)
# ('encounters_reasoncode_359817006', 0.0001)
# ('encounters_reasoncode_35999006', 0.0001)
# ('encounters_reasoncode_367498001', 0.0001)
# ('encounters_reasoncode_370143000', 0.0001)
# ('encounters_reasoncode_38822007', 0.0001)
# ('encounters_reasoncode_403191005', 0.0001)
# ('encounters_reasoncode_444448004', 0.0001)
# ('encounters_reasoncode_446096008', 0.0001)
# ('encounters_reasoncode_58150001', 0.0001)
# ('encounters_reasoncode_62564004', 0.0001)
# ('encounters_reasoncode_65966004', 0.0001)
# ('encounters_reasoncode_68496003', 0.0001)
# ('encounters_reasoncode_69896004', 0.0001)
# ('encounters_reasoncode_79586000', 0.0001)
# ('encounters_reasoncode_82423001', 0.0001)
# ('encounters_reasoncode_83664006', 0.0001)
# ('encounters_reasoncode_93761005', 0.0001)
# ('encounters_reasoncode_94260004', 0.0001)
# ('encounters_reasoncode_95417003', 0.0001)
# ('patient_ethnicity_arab', 0.0001)
# ('patient_race_other', 0.0001)
# ('procedures_code_104326007.0', 0.0001)
# ('procedures_code_108290001.0', 0.0001)
# ('procedures_code_112790001.0', 0.0001)
# ('procedures_code_1225002.0', 0.0001)
# ('procedures_code_165829005.0', 0.0001)
# ('procedures_code_167271000.0', 0.0001)
# ('procedures_code_168594001.0', 0.0001)
# ('procedures_code_19490002.0', 0.0001)
# ('procedures_code_268425006.0', 0.0001)
# ('procedures_code_269828009.0', 0.0001)
# ('procedures_code_269911007.0', 0.0001)
# ('procedures_code_29303009.0', 0.0001)
# ('procedures_code_311791003.0', 0.0001)
# ('procedures_code_35025007.0', 0.0001)
# ('procedures_code_384700001.0', 0.0001)
# ('procedures_code_410006001.0', 0.0001)
# ('procedures_code_418891003.0', 0.0001)
# ('procedures_code_426701000119108.0', 0.0001)
# ('procedures_code_433236007.0', 0.0001)
# ('procedures_code_44608003.0', 0.0001)
# ('procedures_code_45595009.0', 0.0001)
# ('procedures_code_46706006.0', 0.0001)
# ('procedures_code_52765003.0', 0.0001)
# ('procedures_code_60027007.0', 0.0001)
# ('procedures_code_65575008.0', 0.0001)
# ('procedures_code_65588006.0', 0.0001)
# ('procedures_code_698354004.0', 0.0001)
# ('procedures_code_74016001.0', 0.0001)
# ('procedures_code_755621000000101.0', 0.0001)
# ('procedures_code_82078001.0', 0.0001)
# ('providers_utilization', 0.168)
# ('organizations_revenue', 0.1545)
# ('patient_healthcare_coverage', 0.0777)
# ('patient_healthcare_expenses', 0.0678)
# ('procedures_base_cost', 0.0605)
# ('age', 0.058)
# ('encounters_code_424441002', 0.0541)
# ('encounters_payer_coverage', 0.0215)
# ('procedures_code_225158009.0', 0.0194)
# ('procedures_code_180256009.0', 0.0138)
# ('providers_speciality_M', 0.0131)
# ('encounters_encounterclass_outpatient', 0.0113)
# ('procedures_code_274804006.0', 0.0108)
# ('encounters_code_185345009', 0.01)
# ('encounters_reasoncode_72892002', 0.0093)
# ('encounters_code_185347001', 0.0092)
# ('encounters_code_702927004', 0.0084)
# ('encounters_code_424619006', 0.0083)
# ('patient_gender_M', 0.0082)
# ('encounters_code_390906007', 0.0069)
# ('encounters_code_185349003', 0.0065)
# ('encounters_encounterclass_urgentcare', 0.006)
# ('encounters_encounterclass_inpatient', 0.0054)
# ('encounters_code_371883000', 0.0053)
# ('encounters_encounterclass_emergency', 0.005)
# ('patient_marital_M', 0.005)
# ('procedures_code_118001005.0', 0.005)
# ('procedures_code_265764009.0', 0.0048)
# ('encounters_code_698314001', 0.0047)
# ('procedures_code_1.6335031000119104e+16', 0.0045)
# ('encounters_reasoncode_55822004', 0.0044)
# ('encounters_reasoncode_271737000', 0.0043)
# ('procedures_code_104091002.0', 0.0038)
# ('encounters_code_169762003', 0.0037)
# ('patient_ethnicity_irish', 0.0037)
# ('patient_marital_S', 0.0035)
# ('procedures_code_171207006.0', 0.0032)
# ('patient_ethnicity_italian', 0.0031)
# ('patient_ethnicity_english', 0.003)
# ('encounters_code_50849002', 0.0029)
# ('encounters_code_183460006', 0.0028)
# ('procedures_code_443529005.0', 0.0028)
# ('patient_ethnicity_french', 0.0026)
# ('patient_race_white', 0.0025)
# ('procedures_code_268556000.0', 0.0025)
# ('procedures_code_271442007.0', 0.0025)
# ('procedures_code_399014008.0', 0.0025)
# ('patient_ethnicity_german', 0.0022)
# ('procedures_code_275833003.0', 0.0022)
# ('procedures_code_65200003.0', 0.0022)
# ('patient_ethnicity_american', 0.0021)
# ('patient_ethnicity_polish', 0.0021)
# ('patient_ethnicity_portuguese', 0.002)
# ('procedures_code_428191000124101.0', 0.002)
# ('encounters_code_448337001', 0.0019)
# ('procedures_code_76601001.0', 0.0019)
# ('encounters_reasoncode_88805009', 0.0018)
# ('patient_ethnicity_french_canadian', 0.0018)
# ('procedures_code_5880005.0', 0.0018)
# ('patient_race_black', 0.0017)
# ('encounters_reasoncode_254837009', 0.0016)
# ('patient_ethnicity_chinese', 0.0016)
# ('patient_race_hispanic', 0.0016)
# ('procedures_code_180325003.0', 0.0016)
# ('encounters_reasoncode_444814009', 0.0014)
# ('patient_ethnicity_scottish', 0.0014)
# ('procedures_code_703423002.0', 0.0014)
# ('encounters_code_410429000', 0.0013)
# ('patient_ethnicity_puerto_rican', 0.0013)
# ('patient_ethnicity_russian', 0.0013)
# ('encounters_code_308335008', 0.0012)
# ('encounters_reasoncode_126906006', 0.0012)
# ('encounters_reasoncode_65275009', 0.0012)
# ('procedures_code_169673001.0', 0.0012)
# ('procedures_code_73761001.0', 0.0012)
# ('patient_ethnicity_asian_indian', 0.0011)
# ('patient_ethnicity_dominican', 0.0011)
# ('patient_ethnicity_greek', 0.0011)
# ('patient_ethnicity_swedish', 0.0011)
# ('patient_ethnicity_west_indian', 0.0011)
# ('encounters_code_270427003', 0.001)
# ('encounters_reasoncode_10509002', 0.0009)
# ('encounters_reasoncode_65363002', 0.0009)
# ('patient_ethnicity_central_american', 0.0009)
# ('procedures_code_169230002.0', 0.0009)
# ('procedures_code_31208007.0', 0.0009)
# ('procedures_code_33195004.0', 0.0009)
# ('procedures_code_398171003.0', 0.0009)
# ('patient_ethnicity_mexican', 0.0008)
# ('patient_ethnicity_south_american', 0.0008)
# ('procedures_code_85548006.0', 0.0008)
# ('encounters_reasoncode_195662009', 0.0007)
# ('encounters_reasoncode_36971009', 0.0007)
# ('procedures_code_15081005.0', 0.0007)
# ('procedures_code_18946005.0', 0.0007)
# ('procedures_code_274474001.0', 0.0007)
# ('procedures_code_310861008.0', 0.0007)
# ('procedures_code_386394001.0', 0.0007)
# ('procedures_code_714812005.0', 0.0007)
# ('encounters_reasoncode_239873007', 0.0006)
# ('encounters_total_claim_cost', 0.0006)
# ('procedures_code_1015401000000102.0', 0.0006)
# ('procedures_code_312681000.0', 0.0006)
# ('encounters_base_encounter_cost', 0.0005)
# ('encounters_code_308540004', 0.0005)
# ('encounters_code_310061009', 0.0005)
# ('encounters_code_410410006', 0.0005)
# ('encounters_reasoncode_192127007', 0.0005)
# ('encounters_reasoncode_363406005', 0.0005)
# ('encounters_reasoncode_55680006', 0.0005)
# ('encounters_reasoncode_75498004', 0.0005)
# ('procedures_code_11466000.0', 0.0005)
# ('procedures_code_169690007.0', 0.0005)
# ('procedures_code_18286008.0', 0.0005)
# ('procedures_code_232717009.0', 0.0005)
# ('procedures_code_252160004.0', 0.0005)
# ('procedures_code_274031008.0', 0.0005)
# ('encounters_code_170838006', 0.0004)
# ('encounters_code_230690007', 0.0004)
# ('encounters_code_394701000', 0.0004)
# ('encounters_reasoncode_128613002', 0.0004)
# ('encounters_reasoncode_233678006', 0.0004)
# ('encounters_reasoncode_47505003', 0.0004)
# ('encounters_reasoncode_67811000119102', 0.0004)
# ('encounters_reasoncode_74400008', 0.0004)
# ('procedures_code_10383002.0', 0.0004)
# ('procedures_code_117010004.0', 0.0004)
# ('procedures_code_367336001.0', 0.0004)
# ('procedures_code_399208008.0', 0.0004)
# ('procedures_code_430193006.0', 0.0004)
# ('procedures_code_47758006.0', 0.0004)
# ('procedures_code_51116004.0', 0.0004)
# ('procedures_code_66348005.0', 0.0004)
# ('procedures_code_71651007.0', 0.0004)
# ('procedures_code_90470006.0', 0.0004)
# ('encounters_code_183495009', 0.0003)
# ('encounters_code_185317003', 0.0003)
# ('encounters_code_305408004', 0.0003)
# ('encounters_code_439740005', 0.0003)
# ('encounters_reasoncode_109838007', 0.0003)
# ('encounters_reasoncode_156073000', 0.0003)
# ('encounters_reasoncode_24079001', 0.0003)
# ('encounters_reasoncode_62106007', 0.0003)
# ('patient_ethnicity_american_indian', 0.0003)
# ('patient_race_native', 0.0003)
# ('procedures_code_127783003.0', 0.0003)
# ('procedures_code_14768001.0', 0.0003)
# ('procedures_code_162676008.0', 0.0003)
# ('procedures_code_237001001.0', 0.0003)
# ('procedures_code_305428000.0', 0.0003)
# ('procedures_code_31676001.0', 0.0003)
# ('procedures_code_395123002.0', 0.0003)
# ('procedures_code_415070008.0', 0.0003)
# ('procedures_code_415300000.0', 0.0003)
# ('procedures_code_433112001.0', 0.0003)
# ('procedures_code_447365002.0', 0.0003)
# ('procedures_code_68254000.0', 0.0003)
# ('procedures_code_699253003.0', 0.0003)
# ('procedures_code_90226004.0', 0.0003)
# ('encounters_code_170837001', 0.0002)
# ('encounters_code_183452005', 0.0002)
# ('encounters_code_185389009', 0.0002)
# ('encounters_code_210098006', 0.0002)
# ('encounters_code_316744009', 0.0002)
# ('encounters_code_56876005', 0.0002)
# ('encounters_reasoncode_195967001', 0.0002)
# ('encounters_reasoncode_201834006', 0.0002)
# ('encounters_reasoncode_239872002', 0.0002)
# ('encounters_reasoncode_26929004', 0.0002)
# ('encounters_reasoncode_307731004', 0.0002)
# ('encounters_reasoncode_403190006', 0.0002)
# ('encounters_reasoncode_43878008', 0.0002)
# ('encounters_reasoncode_90560007', 0.0002)
# ('procedures_code_117015009.0', 0.0002)
# ('procedures_code_169553002.0', 0.0002)
# ('procedures_code_228557008.0', 0.0002)
# ('procedures_code_23426006.0', 0.0002)
# ('procedures_code_236974004.0', 0.0002)
# ('procedures_code_28163009.0', 0.0002)
# ('procedures_code_287664005.0', 0.0002)
# ('procedures_code_288086009.0', 0.0002)
# ('procedures_code_301807007.0', 0.0002)
# ('procedures_code_385798007.0', 0.0002)
# ('procedures_code_395142003.0', 0.0002)
# ('procedures_code_43075005.0', 0.0002)
# ('encounters_code_183478001', 0.0001)
# ('encounters_code_223484005', 0.0001)
# ('encounters_code_86013001', 0.0001)
# ('encounters_reasoncode_124171000119105', 0.0001)
# ('encounters_reasoncode_16114001', 0.0001)
# ('encounters_reasoncode_162573006', 0.0001)
# ('encounters_reasoncode_196416002', 0.0001)
# ('encounters_reasoncode_232353008', 0.0001)
# ('encounters_reasoncode_263102004', 0.0001)
# ('encounters_reasoncode_267253006', 0.0001)
# ('encounters_reasoncode_301011002', 0.0001)
# ('encounters_reasoncode_33737001', 0.0001)
# ('encounters_reasoncode_359817006', 0.0001)
# ('encounters_reasoncode_35999006', 0.0001)
# ('encounters_reasoncode_367498001', 0.0001)
# ('encounters_reasoncode_370143000', 0.0001)
# ('encounters_reasoncode_38822007', 0.0001)
# ('encounters_reasoncode_403191005', 0.0001)
# ('encounters_reasoncode_444448004', 0.0001)
# ('encounters_reasoncode_446096008', 0.0001)
# ('encounters_reasoncode_58150001', 0.0001)
# ('encounters_reasoncode_62564004', 0.0001)
# ('encounters_reasoncode_65966004', 0.0001)
# ('encounters_reasoncode_68496003', 0.0001)
# ('encounters_reasoncode_69896004', 0.0001)
# ('encounters_reasoncode_79586000', 0.0001)
# ('encounters_reasoncode_82423001', 0.0001)
# ('encounters_reasoncode_83664006', 0.0001)
# ('encounters_reasoncode_93761005', 0.0001)
# ('encounters_reasoncode_94260004', 0.0001)
# ('encounters_reasoncode_95417003', 0.0001)
# ('patient_ethnicity_arab', 0.0001)
# ('patient_race_other', 0.0001)
# ('procedures_code_104326007.0', 0.0001)
# ('procedures_code_108290001.0', 0.0001)
# ('procedures_code_112790001.0', 0.0001)
# ('procedures_code_1225002.0', 0.0001)
# ('procedures_code_165829005.0', 0.0001)
# ('procedures_code_167271000.0', 0.0001)
# ('procedures_code_168594001.0', 0.0001)
# ('procedures_code_19490002.0', 0.0001)
# ('procedures_code_268425006.0', 0.0001)
# ('procedures_code_269828009.0', 0.0001)
# ('procedures_code_269911007.0', 0.0001)
# ('procedures_code_29303009.0', 0.0001)
# ('procedures_code_311791003.0', 0.0001)
# ('procedures_code_35025007.0', 0.0001)
# ('procedures_code_384700001.0', 0.0001)
# ('procedures_code_410006001.0', 0.0001)
# ('procedures_code_418891003.0', 0.0001)
# ('procedures_code_426701000119108.0', 0.0001)
# ('procedures_code_433236007.0', 0.0001)
# ('procedures_code_44608003.0', 0.0001)
# ('procedures_code_45595009.0', 0.0001)
# ('procedures_code_46706006.0', 0.0001)
# ('procedures_code_52765003.0', 0.0001)
# ('procedures_code_60027007.0', 0.0001)
# ('procedures_code_65575008.0', 0.0001)
# ('procedures_code_65588006.0', 0.0001)
# ('procedures_code_698354004.0', 0.0001)
# ('procedures_code_74016001.0', 0.0001)
# ('procedures_code_755621000000101.0', 0.0001)
# ('procedures_code_82078001.0', 0.0001)
# 2019-10-30 01:01:48,167 sagemaker-containers INFO     Reporting training SUCCESS
# 2019-10-30 01:02:38 Completed - Training job completed
# Training seconds: 920
# Billable seconds: 920

# %% [markdown]
# ### Launching a tuning job with the Python SDK

# %%
# we use the Hyperparameter Tuner
from sagemaker.tuner import IntegerParameter

# Define exploration boundaries
hyperparameter_ranges = {
    'estimators': IntegerParameter(18, 20)}

# create Optimizer
Optimizer = sagemaker.tuner.HyperparameterTuner(
    estimator=sklearn_model,
    hyperparameter_ranges=hyperparameter_ranges,
    base_tuning_job_name='RF-tuner',
    objective_type='Maximize',
    objective_metric_name='RF Accuracy',
    metric_definitions=[
        {'Name': 'RF Accuracy',
         'Regex': 'RF Accuracy (\d\.\d+)'}],  # extract tracked metric from logs with regexp 
    max_jobs=2,
    max_parallel_jobs=2)

# %%
## Launch Hyperparameter training job 
Optimizer.fit({'train': s3_train_data})

# %%
## Get the status of Hyperparameter training job
import boto3
from sagemaker.tuner import HyperparameterTuner
boto3.client('sagemaker').describe_hyper_parameter_tuning_job(
    HyperParameterTuningJobName=Optimizer.latest_tuning_job.job_name)['HyperParameterTuningJobStatus']
# Out:
# 'InProgress'

# %%
# get tuner results in a df
results = Optimizer.analytics().dataframe()
results.head()
# Out:
#    FinalObjectiveValue  TrainingElapsedTimeSeconds           TrainingEndTime  \
# 0             0.856450                       808.0 2019-10-30 01:21:15+00:00
# 1             0.855464                       812.0 2019-10-30 01:21:15+00:00
#
#                      TrainingJobName TrainingJobStatus  \
# 0  RF-tuner-191030-0105-002-473b24c9         Completed
# 1  RF-tuner-191030-0105-001-91f328f7         Completed
#
#           TrainingStartTime  estimators
# 0 2019-10-30 01:07:47+00:00        18.0
# 1 2019-10-30 01:07:43+00:00        19.0

# %%
## Creating a model
from sagemaker.mxnet.model import MXNetModel

sagemaker_model = MXNetModel(model_data='s3://path/to/model.tar.gz',
                             role='arn:aws:iam::accid:sagemaker-role',
                             entry_point='entry_point.py')

# %%
# Deploy my estimator to a SageMaker Endpoint and get a Predictor
#training_job_name = sklearn_estimator.latest_training_job.name
#training_job_name = "sagemaker-scikit-learn-2019-10-05-07-30-22-718"
#attached_estimator = SKLearn.attach(training_job_name)
#predictor = attached_estimator.deploy(instance_type='ml.m4.xlarge',initial_instance_count=1)

# %% [markdown]
# Batch transform training data

# %%
# Define a SKLearn Transformer from the trained SKLearn Estimator
transformer = sklearn_preprocessor.transformer(
    instance_count=1, 
    instance_type='ml.m4.xlarge',
    assemble_with = 'Line',
    accept = 'text/csv')

# Preprocess training input
transformer.transform(train_input, content_type='text/csv')
print('Waiting for transform job: ' + transformer.latest_transform_job.job_name)
transformer.wait()
preprocessed_train = transformer.output_path
